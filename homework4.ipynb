# %% [markdown]
# <h2> Homework 4 </h2>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("../data.csv")

# %%
data.head()

data = data.rename(columns={'num       ': 'num'})

# %% [markdown]
# (a) Randomly select a test dataset consisting of 20% of the examples with num= 0 and 20% of
# the examples with num= 1. The remaining examples will constitute the training data. Plot
# histograms of each of the features for the training data and the test data.
#
#
# Response:

# %%
from sklearn.model_selection import train_test_split


train, test =  train_test_split(
   data, test_size=0.2, random_state=42)

# %%
import matplotlib.pyplot as plt


fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Age')
ax1.set_title('Train')
ax1.hist(train['age'], density=True, bins=20)
ax2.set_title('Test')
ax2.hist(test['age'],density=True, bins=20)
# Out:
# (array([0.01994018, 0.00997009, 0.03988036, 0.00997009, 0.02991027,
#         0.02991027, 0.02991027, 0.02991027, 0.04985045, 0.02991027,
#         0.04985045, 0.06979063, 0.04985045, 0.01994018, 0.05982054,
#         0.02991027, 0.        , 0.00997009, 0.        , 0.01994018]),
#  array([32. , 33.7, 35.4, 37.1, 38.8, 40.5, 42.2, 43.9, 45.6, 47.3, 49. ,
#         50.7, 52.4, 54.1, 55.8, 57.5, 59.2, 60.9, 62.6, 64.3, 66. ]),
#  <a list of 20 Patch objects>)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Sex')
ax1.set_title('Train')
ax1.hist(train['sex'], density=True, bins=2)
ax2.set_title('Test')
ax2.hist(test['sex'],density=True, bins=2)
# Out:
# (array([0.6779661, 1.3220339]),
#  array([0. , 0.5, 1. ]),
#  <a list of 2 Patch objects>)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('CP')
ax1.set_title('Train')
ax1.hist(train['cp'], density=True, bins=4)
ax2.set_title('Test')
ax2.hist(test['cp'],density=True, bins=4)
# Out:
# (array([0.04519774, 0.38418079, 0.27118644, 0.63276836]),
#  array([1.  , 1.75, 2.5 , 3.25, 4.  ]),
#  <a list of 4 Patch objects>)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('trestbps')
ax1.set_title('Train')
ax1.hist(train['trestbps'], density=True, bins=15)
ax2.set_title('Test')
ax2.hist(test['trestbps'],density=True, bins=15)
# Out:
# (array([0.31405783, 0.0448654 , 0.02991027, 0.0448654 , 0.13459621,
#         0.01495513, 0.05982054, 0.02991027, 0.01495513, 0.01495513,
#         0.0448654 , 0.05982054, 0.01495513, 0.02991027, 0.02991027]),
#  array([ 0.        ,  1.13333333,  2.26666667,  3.4       ,  4.53333333,
#          5.66666667,  6.8       ,  7.93333333,  9.06666667, 10.2       ,
#         11.33333333, 12.46666667, 13.6       , 14.73333333, 15.86666667,
#         17.        ]),
#  <a list of 15 Patch objects>)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('chol')
ax1.set_title('Train')
ax1.hist(train['chol'], density=True, bins=15)
ax2.set_title('Test')
ax2.hist(test['chol'],density=True, bins=15)
# Out:
# (array([0.02163722, 0.04868374, 0.02163722, 0.01622791, 0.02163722,
#         0.02704652, 0.01622791, 0.02704652, 0.01622791, 0.01622791,
#         0.01622791, 0.01622791, 0.01622791, 0.01622791, 0.02163722]),
#  array([ 0.        ,  3.13333333,  6.26666667,  9.4       , 12.53333333,
#         15.66666667, 18.8       , 21.93333333, 25.06666667, 28.2       ,
#         31.33333333, 34.46666667, 37.6       , 40.73333333, 43.86666667,
#         47.        ]),
#  <a list of 15 Patch objects>)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('fbs')
ax1.set_title('Train')
ax1.hist(train['fbs'], density=True, bins=3)
ax2.set_title('Test')
ax2.hist(test['fbs'],density=True, bins=3)
# Out:
# (array([2.79661017, 0.        , 0.20338983]),
#  array([0.        , 0.33333333, 0.66666667, 1.        ]),
#  <a list of 3 Patch objects>)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('restecg')
ax1.set_title('Train')
ax1.hist(train['restecg'], density=True, bins=2)
ax2.set_title('Test')
ax2.hist(test['restecg'],density=True, bins=2)
# Out:
# (array([1.49152542, 0.50847458]),
#  array([0. , 0.5, 1. ]),
#  <a list of 2 Patch objects>)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('thalach')
ax1.set_title('Train')
ax1.hist(train['thalach'], density=True, bins=10)
ax2.set_title('Test')
ax2.hist(test['thalach'],density=True, bins=10)
# Out:
# (array([0.0529661 , 0.02648305, 0.0529661 , 0.02648305, 0.02648305,
#         0.02648305, 0.03707627, 0.01588983, 0.02118644, 0.02648305]),
#  array([ 0. ,  3.2,  6.4,  9.6, 12.8, 16. , 19.2, 22.4, 25.6, 28.8, 32. ]),
#  <a list of 10 Patch objects>)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('exang')
ax1.set_title('Train')
ax1.hist(train['exang'], density=True, bins=2)
ax2.set_title('Test')
ax2.hist(test['exang'],density=True, bins=2)
# Out:
# (array([0.61016949, 0.38983051]),
#  array([0., 1., 2.]),
#  <a list of 2 Patch objects>)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('oldpeak')
ax1.set_title('Train')
ax1.hist(train['oldpeak'], density=True, bins=3)
ax2.set_title('Test')
ax2.hist(test['oldpeak'],density=True, bins=3)
# Out:
# (array([0.49830508, 0.08135593, 0.02033898]),
#  array([0.        , 1.66666667, 3.33333333, 5.        ]),
#  <a list of 3 Patch objects>)

# %% [markdown]
# (b) Use logistic regression to learn a binary classifier that predicts the diagnosis of heart disease
# using only the features: age, sex, cp, chol. Plot the ROC curve and the precision-recall
# curve for your classifier. Remove from your training set any example for which any of
# these features is missing. You may use an existing computer package that computes the
# logistic regression, such as scikit-learn. You may choose to follow other data cleaning steps
# in the step-by-step guide
# Response:

# %%
#Checking for missing vals
# Missing vals 

train = train[train.age != '?']
train = train[train.sex != '?']
train = train[train.cp != '?']
train = train[train.chol != '?']
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
from sklearn import linear_model
from scipy.special import expit

X = train[['age', 'sex', 'cp', 'chol']]
y = train[['num']]

# Fit the classifier
clf = linear_model.LogisticRegression()
clf.fit(X, y)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
c
proba = clf.predict_proba(test[['age', 'sex', 'cp', 'chol']])

proba = proba[:, 1]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
## get ROC 

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

zeros = [0 for _ in range(len(test['num']))]

ns_auc = roc_auc_score(test['num'], zeros)
predicted_auc = roc_auc_score(test['num'], proba)

# %%
## Plot ROC and Precision

# summarize scores
print('ROC AUC=%.3f' % (predicted_auc))

regular_fpr, regular_tpr, _ = roc_curve(test['num'], zeros)
false_positive_rate, true_positive_rate, _ = roc_curve(test['num'], proba)

plt.plot(regular_fpr, regular_tpr, linestyle='--')
plt.plot(false_positive_rate, true_positive_rate, marker='.')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()
# Out:
# ROC AUC=0.859

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc


yhat = clf.predict(test[['age', 'sex', 'cp', 'chol']])
precision, recall, _ = precision_recall_curve(test['num'], proba)
lr_f1, lr_auc = f1_score(test['num'], yhat), auc(recall, precision)
print(f'Average Precision: {precision.mean()}')
print(f'Average Recall: {recall.mean()}')
no_skill = len(test['num'][test['num']==1]) / len(test['num'])
plt.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
plt.plot(recall, precision, marker='.', label='Logistic')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()

plt.show()
# Out:
# Average Precision: 0.6952874510763467
# Average Recall: 0.6302631578947369

# %% [markdown]
# (c) Same as part (b), but use the following features: age, sex, cp, trestbps, chol, fbs, restecg,
# thalach, exang, oldpeak.
# Response:

# %%
from sklearn import linear_model
from scipy.special import expit

train = train[train.age != '?']
train = train[train.sex != '?']
train = train[train.cp != '?']
train = train[train.chol != '?']
train = train[train.fbs != '?']
train = train[train.restecg != '?']
train = train[train.thalach != '?']
train = train[train.exang != '?']
train = train[train.oldpeak != '?']
train = train[train.num != '?']

X = train[['age', 'sex', 'cp', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak']]
y = train[['num']]

# Fit the classifier
clf = linear_model.LogisticRegression()
clf.fit(X, y)
test = test[test.age != '?']
test = test[test.sex != '?']
test = test[test.cp != '?']
test = test[test.chol != '?']
test = test[test.fbs != '?']
test = test[test.restecg != '?']
test = test[test.thalach != '?']
test = test[test.exang != '?']
test = test[test.oldpeak != '?']
proba = clf.predict_proba(test[['age', 'sex', 'cp', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak']])

proba = proba[:, 1]

from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

zeros = [0 for _ in range(len(test['num']))]

ns_auc = roc_auc_score(test['num'], zeros)
predicted_auc = roc_auc_score(test['num'], proba)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...

# %%
## Plot ROC and Precision

# summarize scores
print('ROC AUC=%.3f' % (predicted_auc))

regular_fpr, regular_tpr, _ = roc_curve(test['num'], zeros)
false_positive_rate, true_positive_rate, _ = roc_curve(test['num'], proba)

plt.plot(regular_fpr, regular_tpr, linestyle='--')
plt.plot(false_positive_rate, true_positive_rate, marker='.')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()
# Out:
# ROC AUC=0.923

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc


yhat = clf.predict(test[['age', 'sex', 'cp', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak']])
precision, recall, _ = precision_recall_curve(test['num'], proba)
lr_f1, lr_auc = f1_score(test['num'], yhat), auc(recall, precision)
print(f'Average Precision: {precision.mean()}')
print(f'Average Recall: {recall.mean()}')
no_skill = len(test['num'][test['num']==1]) / len(test['num'])
plt.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
plt.plot(recall, precision, marker='.', label='Logistic')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()

plt.show()
# Out:
# Average Precision: 0.804198331582495
# Average Recall: 0.6614509246088194

# %% [markdown]
# (d) Compare your two classifiers. Which would you argue is better for deployment in practice?
# Response:

# %% [markdown]
# Having a lot of false negatives for heart disease can be extremely detrimental. This means we must aim to get a very high recall. Precision is also important but less important in this problem. We can see that the second classifier has both a better precision and recall and should be utilized.
#
#
# For the Roc and Auc curves we find the first classifier can differentiate between classes with approximately 85% accuracy while the second classifier does so with approximately a 90% accurracy. The second classifier is again superior.

# %% [markdown]
# (e) Solve the logistic regression in part (b) using gradient descent and a cross-entropy loss.
# Plot the ROC curve and the precision-recall curve.
# Response:
#
#
# I am planning on using the SGD classifier because it is a logistic regression classifier.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <h3> First Using Sklearn </h3>

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import log_loss


x_train = train[['age', 'sex', 'cp', 'chol']]
y_train = train[['num']]
x_test = test[['age', 'sex', 'cp', 'chol']]
y_test = test[['num']]

clf = SGDClassifier(loss="log", penalty="l1", max_iter=150, alpha=0.01, random_state=29)
clf.fit(x_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDClassifier(alpha=0.01, loss='log', max_iter=150, penalty='l1',
#               random_state=29)

# %%
from sklearn.metrics import accuracy_score
pr = clf.predict(x_test)

score = accuracy_score(y_test, pr)


from sklearn.metrics import average_precision_score
y_true = y_test
y_scores = pr
ap = average_precision_score(y_true, y_scores)

# %%
print(f'Accuracy: {score}')

print(f'Average Precision: {ap}')
# Out:
# Accuracy: 0.6538461538461539
# Average Precision: 0.49938657833394673

# %%
from sklearn.metrics import PrecisionRecallDisplay

display = PrecisionRecallDisplay.from_estimator(
    clf, x_test, y_test, name="LinearSVC"
)
_ = display.ax_.set_title("2-class Precision-Recall curve")

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics

fpr, tpr, thresholds = metrics.roc_curve(y_test, pr)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                  estimator_name='example estimator')
display.plot()

plt.show()

# %% [markdown]
# (f) Solve the logistic regression in part (b) using gradient descent and a square loss. Plot the
# ROC curve and the precision-recall curve. How does your classifier compare to that from
# part (e)?

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import log_loss
from sklearn.metrics import make_scorer



loss_function = make_scorer(square_loss, greater_is_better=False)
x_train = train[['age', 'sex', 'cp', 'chol']]
y_train = train[['num']]
x_test = test[['age', 'sex', 'cp', 'chol']]
y_test = test[['num']]

clf = SGDClassifier(loss='squared_loss', penalty="l1", max_iter=150, alpha=0.01, random_state=29)
clf.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-257-aa6450a5c467> in <module>
#       5
#       6
# ----> 7 loss_function = make_scorer(square_loss, greater_is_better=False)
#       8 x_train = train[['age', 'sex', 'cp', 'chol']]
#       9 y_train = train[['num']]
#
# NameError: name 'square_loss' is not defined

# %%
from sklearn.metrics import accuracy_score
pr = clf.predict(x_test)

score = accuracy_score(y_test, pr)


from sklearn.metrics import average_precision_score
y_true = y_test
y_scores = pr
ap = average_precision_score(y_true, y_scores)


print(f'Accuracy: {score}')

print(f'Average Precision: {ap}')

# %%
display = PrecisionRecallDisplay.from_estimator(
    clf, x_test, y_test, name="LinearSVC"
)
_ = display.ax_.set_title("2-class Precision-Recall curve")

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test, pr)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                  estimator_name='example estimator')
display.plot()

plt.show()

# %%
X_test_b = tf.cast(X_test_b, tf.float32)
testPredictions = logistic_regression(X_test_b)
fpr, tpr, thresholds = roc_curve(y_test_b, testPredictions[:,1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve with Cross Entropy Loss')
plt.plot(fpr,tpr)
plt.show()

precision, recall, thresholds = precision_recall_curve(y_test_b, testPredictions[:,1])
no_skill = len(y_test_b[y_test_b==1]) / len(y_test_b)
plt.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
plt.plot(recall, precision, marker='.', label='Logistic')
# axis labels
plt.title('Precision/Recall curve with Cross Entropy Loss')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# <h3> Conclusion given Sklearn </h3>
#
# We set our random seed to be the same so that the models are comparable. We can see using the cross entropy or log loss is better than using the squared loss. Our precision and accuracy are also much greater when using the log loss.

# %% [markdown]
# <h3> Using Tensor Flow </h3>

# %%
# Sigmoid Cross Entropy Cost Function

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

num_classes = 2 

num_features = 4 

x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)

# Flatten images to 1-D vector of 784 features (28*28).

x_train, x_test = x_train.reshape([-1, num_features]), x_test.reshape([-1, num_features])


model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, activation='sigmoid')
])

auc = tf.keras.metrics.AUC(num_thresholds=3)

accuracy = tf.keras.metrics.Accuracy(
    name='accuracy', dtype=None
)
precision = tf.keras.metrics.Precision(
    thresholds=None, top_k=None, class_id=None, name=None, dtype=None
)

recall = tf.keras.metrics.Recall(
    thresholds=None, top_k=None, class_id=None, name=None, dtype=None
)

optimizer = tf.train.GradientDescentOptimizer(0.005)

model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=optimizer, metrics=[auc, accuracy, precision, recall])

y_train = np.array(y_train, np.float32)

model.fit(x_train, y_train, epochs=1000)

# %%
predictions = model.predict(x_test)

# %%
preds = np.concatenate( predictions, axis=0 )

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve

X_test_b = tf.cast(x_test, tf.float32)
y_test_b = tf.cast(y_test, tf.float32)
# testPredictions = model.predict(x_test)
fpr, tpr, thresholds = roc_curve(y_test, preds)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve with Cross Entropy Loss')
plt.plot(fpr,tpr)
plt.show()

# precision, recall, thresholds = precision_recall_curve(y_test_b, testPredictions[:,1])
# no_skill = len(y_test_b[y_test_b==1]) / len(y_test_b)
# plt.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
# plt.plot(recall, precision, marker='.', label='Logistic')
# # axis labels
# plt.title('Precision/Recall curve with Cross Entropy Loss')
# plt.xlabel('Recall')
# plt.ylabel('Precision')
# plt.show()

# %%
## This is from dan 
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score, recall_score, precision_score, average_precision_score, f1_score
from sklearn.metrics import plot_roc_curve
X, y = x_train, y_train
# X, y = get_features_and_target_arrays(df_train, numeric_cols_b, cat_cols_b, scaler)
oneHot = OneHotEncoder()
x_orig = X
y_init = y
y_orig = y
# y_orig = y.values.reshape(-1,1)#y.array.reshape(-1, 1) # Encoding x_orig
oneHot.fit(x_orig)
x = oneHot.transform(x_orig).toarray()
# Encoding y_orig
oneHot.fit(y_orig)
y = oneHot.transform(y_orig).toarray()


alpha, epochs = 0.0035, 50 
m, n = x.shape

X = tf.placeholder(tf.float32, [None, n])
# Since this is a binary classification problem, # Y can take only 2 values.
Y = tf.placeholder(tf.float32, [None, 2])
# Trainable Variable Weights
W = tf.Variable(tf.zeros([n, 4]))
# Trainable Variable Bias
b = tf.Variable(tf.zeros([4, 2]))

Y_hat = tf.nn.sigmoid(tf.matmul(X, W))
# Sigmoid Cross Entropy Cost Function


cost = tf.nn.sigmoid_cross_entropy_with_logits( logits = Y_hat, labels = Y)
# Gradient Descent Optimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate = alpha).minimize(cost)
# Global Variables Initializer
init = tf.global_variables_initializer()
with tf.Session() as sess:
    # Initializing the Variables 
    sess.run(init)
# Lists for storing the changing Cost and Accuracy in every Epoch 
    cost_history, accuracy_history = [], []
    # Iterating through all the epochs
    for epoch in range(epochs):
        cost_per_epoch = 0
        # Running the Optimizer
        sess.run(optimizer, feed_dict = {X : x, Y : y})
        # Calculating cost on current Epoch
        c = sess.run(cost, feed_dict = {X : x, Y : y})
        # Calculating accuracy on current Epoch 
        correct_prediction = tf.equal(tf.argmax(Y_hat, 1), tf.argmax(Y, 1))
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        # Storing Cost and Accuracy to the history 
        cost_history.append(sum(sum(c))) 
        accuracy_history.append(accuracy.eval({X : x, Y : y}) * 100)
        # Displaying result on current Epoch 
        if epoch % 100 == 0 and epoch != 0:
            print("Epoch" + str(epoch) + " Cost: " + str(cost_history[-1]))

    Weight = sess.run(W) 
    Bias = sess.run(b)
    # Final Accuracy 
    correct_prediction = tf.equal(tf.argmax(Y_hat, 1), tf.argmax(Y, 1))

    # Optimized Weight
    # Optimized Bias

    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("\nAccuracy:", accuracy_history[-1], "%")

clf = LogisticRegression(penalty='none')

clf.fit(x_orig,y_init) 
plot_roc_curve(clf,x_test,y_test)

# %%
print(Bias)

# %% [markdown]
# We actually get much lower accuracy with the tensorflow option.

# %%
# Sigmoid Cross Entropy Cost Function

import tensorflow as tf

num_classes = 2 # 0 to 9 digits

num_features = 4 # 28*28

x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)

# Flatten images to 1-D vector of 784 features (28*28).

x_train, x_test = x_train.reshape([-1, num_features]), x_test.reshape([-1, num_features])


model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, activation='sigmoid')
])

auc = tf.keras.metrics.AUC(num_thresholds=3)

accuracy = tf.keras.metrics.Accuracy(
    name='accuracy', dtype=None
)
precision = tf.keras.metrics.Precision(
    thresholds=None, top_k=None, class_id=None, name=None, dtype=None
)

recall = tf.keras.metrics.Recall(
    thresholds=None, top_k=None, class_id=None, name=None, dtype=None
)


model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer=tf.keras.optimizers.SGD(
    learning_rate=0.001, momentum=0.0, nesterov=False, name='SGD'
), metrics=[auc, accuracy, precision, recall])
model.fit(x_train, y_train, epochs=500)

# %%
print(auc.result().numpy())
print(accuracy.result().numpy())
print(precision.result().numpy())
print(recall.result().numpy())

# %% [markdown]
# <h1> This is the right answer </h1>

# %%
from __future__ import absolute_import, division, print_function

import tensorflow as tf

import numpy as np

# %%
# (x_train, y_train), (x_test, y_test) = mnist.load_data()

# # Convert to float32.

# x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)

# # Flatten images to 1-D vector of 784 features (28*28).

# x_train, x_test = x_train.reshape([-1, num_features]), x_test.reshape([-1, num_features])

# # Normalize images value from [0, 255] to [0, 1].

# x_train, x_test = x_train / 255., x_test / 255.

# %%
num_classes = 2 # 0 to 9 digits

num_features = 4 # 28*28

# Training parameters.

learning_rate = 0.01

training_steps = 1000

batch_size = 256

display_step = 50

# %%
# train_data=tf.data.Dataset.from_tensor_slices((x_train,y_train))

# train_data=train_data.repeat().shuffle(5000).batch(batch_size).prefetch(1)

# %%
# Weight of shape [784, 10], the 28*28 image features, and a total number of classes.

W = tf.Variable(tf.ones([num_features, num_classes]), name="weight")

W = tf.cast(W, tf.int32)

# Bias of shape [10], the total number of classes.

b = tf.Variable(tf.zeros([num_classes]), name="bias")

b = tf.cast(b, tf.int32)

# %%
# Logistic regression (Wx + b).
@tf.function
def logistic_regression(x):

    # Apply softmax to normalize the logits to a probability distribution.
    print('In logistic')
    
    return tf.nn.softmax(tf.cast(tf.matmul(x, W),tf.float32) + tf.cast(b, tf.float32))

# Cross-Entropy loss function.
@tf.function
def cross_entropy(y_pred, y_true):

    # Encode label to a one hot vector.

    y_true = tf.one_hot(y_true, depth=num_classes)

    # Clip prediction values to avoid log(0) error.

    y_pred = tf.clip_by_value(y_pred, 1e-9, 1.)

    # Compute cross-entropy.

    return tf.reduce_mean(-tf.reduce_sum(y_true * tf.math.log(y_pred)))

# %%
# Accuracy metric.
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
@tf.function
def accuracy(y_pred, y_true):

# Predicted class is the index of the highest score in prediction vector (i.e. argmax).

    correct_prediction = tf.equal(tf.argmax(y_pred, 1), tf.cast(y_true, tf.int64))

    return tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# Stochastic gradient descent optimizer.

optimizer = tf.train.GradientDescentOptimizer(learning_rate)


# optimizer = tf.optimizers.SGD(learning_rate)

# %%
# Optimization process. 


@tf.function
def run_optimization(x, y):

# Wrap computation inside a GradientTape for automatic differentiation.
    print('In run optimization')
    with tf.GradientTape() as g:
        
        print('in gradient')

        pred = logistic_regression(x)
        print('passed logistic')

        loss = cross_entropy(pred, y)

    # Compute gradients.
        print('Below is loss')
        print(loss)

    gradients = g.gradient(loss, [W, b])

    print('calculated gradient')
    print('in gradient')
    print(gradients)
    # Update W and b following gradients.

#     optimizer.apply_gradients(zip(gradients, [W, b]))
    
#     print('optimizer applied gradients')

# %%
# Run training for the given number of steps.

x_train = x_train.astype('int32')
y_train = y_train.astype('int32')

for step in range(training_steps):

    # Run the optimization to update W and b values.

    run_optimization(x_train, y_train)

    

#     if step % display_step == 0:

#         pred = logistic_regression(x_train)

#         loss = cross_entropy(pred, y_train)

#         acc = accuracy(pred, y_train)

#         print("step: %i, loss: %f, accuracy: %f" % (step, loss, acc))
# Out:
# In run optimization
# in gradient
# passed logistic
# Below is loss
# Tensor("PartitionedCall_1:0", shape=(), dtype=float32)
# WARNING:tensorflow:The dtype of the source tensor must be floating (e.g. tf.float32) when calling GradientTape.gradient, got tf.int32
# WARNING:tensorflow:The dtype of the source tensor must be floating (e.g. tf.float32) when calling GradientTape.gradient, got tf.int32
# calculated gradient
# in gradient
# [None, None]
